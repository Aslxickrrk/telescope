# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
import torch

# Load model
print("Loading AI model...")
model_name = "distilgpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# Loading AI model...
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# Simple example
text = "The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in "
print(f"\nStarting text: '{text}'")
print("\nGenerating word by word...\n")

# Generate 5 words, one at a time
current_text = text
steps = 30
k = 3
for step in range(steps):
    print(f"--- Step {step + 1} ---")
    print(f"Current: '{current_text}'")
    
    # Encode current text
    input_ids = tokenizer.encode(current_text, return_tensors="pt")
    
    # Get predictions
    with torch.no_grad():
        outputs = model(input_ids)
        predictions = outputs.logits
    
    # Get the predictions for the NEXT token
    next_token_logits = predictions[0, -1, :]
    next_token_probs = torch.softmax(next_token_logits, dim=0)
    
    # Get top 5 predictions
    top_probs, top_indices = torch.topk(next_token_probs, 5)
    
    print("Top 5 next word predictions:")
    for i, (prob, idx) in enumerate(zip(top_probs, top_indices)):
        word = tokenizer.decode([idx])
        print(f"  {i+1}. '{word}' ({prob.item()*100:.1f}% confident)")
    
    K = 10  # Only consider top 10 tokens

    # Get top K candidates
    top_k_probs, top_k_indices = torch.topk(next_token_probs, K)
    
    # Renormalize probabilities (make them sum to 1 again)
    top_k_probs_normalized = top_k_probs / top_k_probs.sum()
    
    # Randomly sample from these K tokens according to their probabilities
    sampled_index = torch.multinomial(top_k_probs_normalized, num_samples=1).item()
    
    # Get the actual token
    next_token_id = top_k_indices[sampled_index].item()
    
    next_word = tokenizer.decode([next_token_id])
    current_text += next_word
    
    print(f"✓ Chosen: '{next_word}'")
    print(f"New text: '{current_text}'\n")

print(f"\nFinal generated text: '{current_text}'")
# Out:
# Starting text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in '
#
# Generating word by word...
#
# --- Step 1 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in '
# Top 5 next word predictions:
#   1. 'vern' (40.5% confident)
#   2. 'ips' (4.6% confident)
#   3. 'iced' (4.4% confident)
#   4. ' ' (4.2% confident)
#   5. 'Â' (3.4% confident)
# ✓ Chosen: 'ips'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ips'
#
# --- Step 2 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ips'
# Top 5 next word predictions:
#   1. 'ilateral' (33.1% confident)
#   2. 'um' (14.7% confident)
#   3. 'ic' (11.7% confident)
#   4. 'ac' (8.1% confident)
#   5. 'ilon' (4.0% confident)
# ✓ Chosen: 'ac'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac'
#
# --- Step 3 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac'
# Top 5 next word predictions:
#   1. 'char' (9.2% confident)
#   2. 'itis' (8.6% confident)
#   3. 'hem' (7.4% confident)
#   4. 'cial' (5.5% confident)
#   5. ',' (5.2% confident)
# ✓ Chosen: ','
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac,'
#
# --- Step 4 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac,'
# Top 5 next word predictions:
#   1. ' and' (8.3% confident)
#   2. ' ' (8.1% confident)
#   3. ' which' (5.6% confident)
#   4. ' but' (3.3% confident)
#   5. ' the' (3.0% confident)
# ✓ Chosen: ' then'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then'
#
# --- Step 5 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then'
# Top 5 next word predictions:
#   1. ' gradually' (13.0% confident)
#   2. ' slowly' (5.4% confident)
#   3. ' continue' (5.0% confident)
#   4. ' the' (3.0% confident)
#   5. ' be' (2.6% confident)
# ✓ Chosen: ' begin'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin'
#
# --- Step 6 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin'
# Top 5 next word predictions:
#   1. ' in' (66.1% confident)
#   2. ' at' (7.5% confident)
#   3. ' with' (3.5% confident)
#   4. ' on' (2.1% confident)
#   5. ' the' (2.0% confident)
# ✓ Chosen: ' in'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in'
#
# --- Step 7 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in'
# Top 5 next word predictions:
#   1. ' ' (69.5% confident)
#   2. ' the' (1.7% confident)
#   3. ' a' (1.7% confident)
#   4. ' l' (0.6% confident)
#   5. ' k' (0.6% confident)
# ✓ Chosen: ' '
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in '
#
# --- Step 8 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in '
# Top 5 next word predictions:
#   1. 'ips' (99.7% confident)
#   2. 'ip' (0.2% confident)
#   3. 'ili' (0.0% confident)
#   4. 'ipp' (0.0% confident)
#   5. 'iph' (0.0% confident)
# ✓ Chosen: 'ips'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ips'
#
# --- Step 9 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ips'
# Top 5 next word predictions:
#   1. 'ac' (98.8% confident)
#   2. 'a' (0.3% confident)
#   3. 'acs' (0.2% confident)
#   4. 'aca' (0.1% confident)
#   5. 'ic' (0.1% confident)
# ✓ Chosen: 'ac'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac'
#
# --- Step 10 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac'
# Top 5 next word predictions:
#   1. ',' (50.7% confident)
#   2. ' and' (11.6% confident)
#   3. '.' (9.3% confident)
#   4. ' in' (2.8% confident)
#   5. ' at' (1.6% confident)
# ✓ Chosen: ','
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac,'
#
# --- Step 11 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac,'
# Top 5 next word predictions:
#   1. ' then' (80.0% confident)
#   2. ' and' (10.8% confident)
#   3. ' followed' (1.8% confident)
#   4. ' or' (0.5% confident)
#   5. ' which' (0.5% confident)
# ✓ Chosen: ' then'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then'
#
# --- Step 12 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then'
# Top 5 next word predictions:
#   1. ' begin' (22.9% confident)
#   2. ' continue' (13.7% confident)
#   3. ' finish' (4.5% confident)
#   4. ' gradually' (4.5% confident)
#   5. ' start' (4.0% confident)
# ✓ Chosen: ' continue'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue'
#
# --- Step 13 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue'
# Top 5 next word predictions:
#   1. ' in' (66.9% confident)
#   2. ' to' (6.6% confident)
#   3. ' on' (3.4% confident)
#   4. ' for' (3.2% confident)
#   5. ' into' (2.2% confident)
# ✓ Chosen: ' in'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in'
#
# --- Step 14 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in'
# Top 5 next word predictions:
#   1. ' ' (94.9% confident)
#   2. ' the' (0.3% confident)
#   3. ' a' (0.2% confident)
#   4. ' l' (0.1% confident)
#   5. ' ' (0.1% confident)
# ✓ Chosen: ' '
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in '
#
# --- Step 15 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in '
# Top 5 next word predictions:
#   1. 'ips' (99.9% confident)
#   2. 'ip' (0.1% confident)
#   3. 'ics' (0.0% confident)
#   4. 'ili' (0.0% confident)
#   5. 'ipp' (0.0% confident)
# ✓ Chosen: 'ips'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ips'
#
# --- Step 16 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ips'
# Top 5 next word predictions:
#   1. 'ac' (99.7% confident)
#   2. 'a' (0.1% confident)
#   3. 'acs' (0.1% confident)
#   4. 'acc' (0.0% confident)
#   5. 'ic' (0.0% confident)
# ✓ Chosen: 'ac'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac'
#
# --- Step 17 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac'
# Top 5 next word predictions:
#   1. ',' (45.5% confident)
#   2. '.' (22.8% confident)
#   3. ' and' (8.8% confident)
#   4. ' until' (2.5% confident)
#   5. ' as' (2.0% confident)
# ✓ Chosen: ','
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac,'
#
# --- Step 18 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac,'
# Top 5 next word predictions:
#   1. ' then' (91.5% confident)
#   2. ' and' (5.8% confident)
#   3. ' followed' (0.2% confident)
#   4. ' before' (0.2% confident)
#   5. ' or' (0.2% confident)
# ✓ Chosen: ' then'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then'
#
# --- Step 19 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then'
# Top 5 next word predictions:
#   1. ' continue' (74.9% confident)
#   2. ' begin' (7.3% confident)
#   3. ' finish' (2.3% confident)
#   4. ' start' (1.8% confident)
#   5. ' proceed' (1.4% confident)
# ✓ Chosen: ' continue'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue'
#
# --- Step 20 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue'
# Top 5 next word predictions:
#   1. ' in' (96.2% confident)
#   2. ' on' (0.7% confident)
#   3. ' for' (0.4% confident)
#   4. ' into' (0.3% confident)
#   5. ' to' (0.3% confident)
# ✓ Chosen: ' in'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in'
#
# --- Step 21 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in'
# Top 5 next word predictions:
#   1. ' ' (97.8% confident)
#   2. ' ' (0.1% confident)
#   3. ' the' (0.1% confident)
#   4. ' .' (0.1% confident)
#   5. ' l' (0.0% confident)
# ✓ Chosen: ' '
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in '
#
# --- Step 22 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in '
# Top 5 next word predictions:
#   1. 'ips' (100.0% confident)
#   2. 'ip' (0.0% confident)
#   3. 'ipped' (0.0% confident)
#   4. 'ps' (0.0% confident)
#   5. 'ics' (0.0% confident)
# ✓ Chosen: 'ips'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ips'
#
# --- Step 23 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ips'
# Top 5 next word predictions:
#   1. 'ac' (99.8% confident)
#   2. 'a' (0.0% confident)
#   3. 'acs' (0.0% confident)
#   4. 'acc' (0.0% confident)
#   5. 'ap' (0.0% confident)
# ✓ Chosen: 'ac'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac'
#
# --- Step 24 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac'
# Top 5 next word predictions:
#   1. ',' (80.2% confident)
#   2. '.' (8.9% confident)
#   3. ' and' (5.4% confident)
#   4. ' as' (0.4% confident)
#   5. ' (' (0.3% confident)
# ✓ Chosen: '.'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac.'
#
# --- Step 25 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac.'
# Top 5 next word predictions:
#   1. '
# ' (26.4% confident)
#   2. ' The' (25.3% confident)
#   3. ' This' (3.3% confident)
#   4. ' It' (3.0% confident)
#   5. '<|endoftext|>' (2.6% confident)
# ✓ Chosen: ' It'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It'
#
# --- Step 26 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It'
# Top 5 next word predictions:
#   1. ' will' (26.1% confident)
#   2. ' is' (25.9% confident)
#   3. ''s' (4.4% confident)
#   4. ' has' (3.0% confident)
#   5. ' can' (2.7% confident)
# ✓ Chosen: ' can'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It can'
#
# --- Step 27 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It can'
# Top 5 next word predictions:
#   1. ' be' (49.3% confident)
#   2. ' also' (14.0% confident)
#   3. ' then' (5.7% confident)
#   4. ' last' (4.8% confident)
#   5. ' take' (4.0% confident)
# ✓ Chosen: ' be'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It can be'
#
# --- Step 28 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It can be'
# Top 5 next word predictions:
#   1. ' used' (23.8% confident)
#   2. ' done' (9.6% confident)
#   3. ' performed' (6.0% confident)
#   4. ' completed' (3.7% confident)
#   5. ' administered' (2.6% confident)
# ✓ Chosen: ' used'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It can be used'
#
# --- Step 29 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It can be used'
# Top 5 next word predictions:
#   1. ' to' (50.4% confident)
#   2. ' for' (14.7% confident)
#   3. ' as' (10.8% confident)
#   4. ' in' (7.8% confident)
#   5. ' by' (3.3% confident)
# ✓ Chosen: ' to'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It can be used to'
#
# --- Step 30 ---
# Current: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It can be used to'
# Top 5 next word predictions:
#   1. ' measure' (13.6% confident)
#   2. ' assess' (10.2% confident)
#   3. ' determine' (8.4% confident)
#   4. ' test' (6.7% confident)
#   5. ' evaluate' (4.3% confident)
# ✓ Chosen: ' determine'
# New text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It can be used to determine'
#
#
# Final generated text: 'The FitnessGram Pacer Test is a multistage aerobic capacity test that progressively gets more difficult as it continues. The 20 meter pacer test will begin in ipsac, then begin in ipsac, then continue in ipsac, then continue in ipsac. It can be used to determine'
